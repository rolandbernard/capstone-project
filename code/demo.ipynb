# %%
from kalman import LinearPhysics
from tracker import Tracker
from detect import PoseDetector
from camera import Camera

import json
import cv2
import torch
torch.set_float32_matmul_precision('high')

# %%
frames = []
all_cams = []
all_caps = []

for i in range(4):
    cap = cv2.VideoCapture(f"./data/salsa/PosterSession/cam{i}.avi")
    # for _ in range(8100):
    # cap = cv2.VideoCapture(f"./data/salsa/CocktailParty/cam{i}.avi")
    for _ in range(1):
        ret, frame = cap.read()
        assert ret
    frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)  # type: ignore
    frame = torch.from_numpy(frame).to("cuda")
    frames.append(frame)
    all_caps.append(cap)
    cam = Camera()
    cam.load_ini(f"./data/salsa/cam{i}.ini")
    cam.to("cuda")
    all_cams.append(cam)

# %%
detect = PoseDetector(model_name="yolo26l-pose")
detect.to("cuda")

# %%
dyn_mat = torch.concat([
    torch.concat([torch.zeros(17*3, 17*3), torch.eye(3*17)], dim=1),
    torch.concat([torch.zeros(17*3, 17*3), torch.eye(3*17)*-0.5], dim=1)
], dim=0)
dyn_cov = torch.diag(torch.tensor([0.05]*3*17 + [5.0]*3*17))

physics = LinearPhysics(dyn_mat, dyn_cov)
physics.to("cuda")

# %%
tracker = Tracker(detect, physics)

# %%
cams = all_cams
imgs = frames

detections = detect.detect(cams, imgs)

# %%
import matplotlib.pyplot as plt

def plt_detect(cam, detections, axes, i = 0):
    skeleton = [[15, 13], [13, 11], [16, 14], [14, 12], [11, 12], [5, 11], [6, 12], [5, 6], [5, 7], [6, 8], [7, 9], [8, 10], [1, 2], [0, 1], [0, 2], [1, 3], [2, 4], [3, 5], [4, 6]]
    kpts = cam.distort_points(detections[0].view(-1, 17, 2))
    # for kp, cov in zip(kpts[i:i+1].cpu(), detections[1][i:i+1].cpu()):
    for kp, cov in zip(kpts.cpu(), detections[1].cpu()):
        cov = torch.diag(cov).view(17, 2)
        for i, j in skeleton:
            if cov[i, 0] < 0.5 and cov[j, 0] < 0.5:
                axes.plot([kp[i, 0], kp[j, 0]], [kp[i, 1], kp[j, 1]], color='red', linewidth=2)
        for k in range(17):
            if cov[k, 0] < 0.5:
                axes.scatter(kp[k, 0], kp[k, 1], s=20, color='#0000ff70')

_, axs = plt.subplots(2, 2, figsize=(10, 8))
axs[0, 0].imshow(imgs[0].cpu().numpy())
plt_detect(cams[0], detections[0], axs[0, 0], 0)
axs[0, 0].axis("off")
axs[0, 1].imshow(imgs[1].cpu().numpy())
plt_detect(cams[1], detections[1], axs[0, 1], 12)
axs[0, 1].axis("off")
axs[1, 0].imshow(imgs[2].cpu().numpy())
plt_detect(cams[2], detections[2], axs[1, 0], 8)
axs[1, 0].axis("off")
axs[1, 1].imshow(imgs[3].cpu().numpy())
plt_detect(cams[3], detections[3], axs[1, 1], 1)
axs[1, 1].axis("off")

plt.tight_layout()
plt.show()

# %%
tracker.update(all_cams, frames)

# %%
for i in range(1, 1500):
    tracker.predict(1 / 15)
    frames = []
    for cap in all_caps:
        ret, frame = cap.read()
        assert ret
        frame = torch.from_numpy(frame).to("cuda")
        frames.append(frame)
    tracker.update(all_cams, frames)
    with open(f"data/demo/{i}.json", "w") as file:
        tracks = [{
            "id": track.id,
            "kpts": track.get_keypoints().tolist(),
            "covs": track.get_covariances().tolist()
        } for track in tracker.get_prediction()]
        json.dump(tracks, file)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 10
#       6         ret, frame = cap.read()
#       7         assert ret
#       8         frame = torch.from_numpy(frame).to("cuda")
#       9         frames.append(frame)
# ---> 10     tracker.update(all_cams, frames)
#      11     with open(f"data/demo/{i}.json", "w") as file:
#      12         tracks = [{
#      13             "id": track.id,
#
# File ~/dev/github/rolandbernard/capstone-project/code/tracker.py:302, in Tracker.update(self, cams, imgs)
#     296 track = self.new_track(mean)
#     297 obf, ob_m, ob_v = kalman.emerge_obs(
#     298     [lambda x, c=cam: c.project_pinhole(x[:17*3].view(-1, 3)).flatten()
#     299      for cam in m_cams],
#     300     m_kpts, m_covs
#     301 )
# --> 302 mean, cov = kalman.eupdate(
#     303     track.mean, track.cov, ob_m, ob_v, obf)
#     304 track.update(mean, cov)
#     305 new_tracks.append(track)
#
# File ~/dev/github/rolandbernard/capstone-project/code/kalman.py:167, in eupdate(mean, cov, obs_mean, obs_cov, obs)
#     159 def eupdate(
#     160     mean: torch.Tensor, cov: torch.Tensor,
#     161     obs_mean: torch.Tensor, obs_cov: torch.Tensor, obs: Callable[[torch.Tensor], torch.Tensor],
#     162 ) -> tuple[torch.Tensor, torch.Tensor]:
#     163     """
#     164     Apply update using Extended Kalman filtering give an observation function,
#     165     but using PyTorch functionality to automatically compute the Jacobian.
#     166     """
# --> 167     return eupdate_ex(mean, cov, obs_mean, obs_cov, obs, lambda x: batched_jacobian(obs, x))
#
# File ~/dev/github/rolandbernard/capstone-project/code/kalman.py:145, in eupdate_ex(mean, cov, obs_mean, obs_cov, obs, obs_jac)
#     140 """
#     141 Apply update using Extended Kalman filtering give an explicit formulation of
#     142 the Jacobian as a function.
#     143 """
#     144 res = obs_mean - obs(mean)
# --> 145 jac = obs_jac(mean)
#     146 return update_res(mean, cov, jac, res, obs_cov)
#
# File ~/dev/github/rolandbernard/capstone-project/code/kalman.py:167, in eupdate.<locals>.<lambda>(x)
#     159 def eupdate(
#     160     mean: torch.Tensor, cov: torch.Tensor,
#     161     obs_mean: torch.Tensor, obs_cov: torch.Tensor, obs: Callable[[torch.Tensor], torch.Tensor],
#     162 ) -> tuple[torch.Tensor, torch.Tensor]:
#     163     """
#     164     Apply update using Extended Kalman filtering give an observation function,
#     165     but using PyTorch functionality to automatically compute the Jacobian.
#     166     """
# --> 167     return eupdate_ex(mean, cov, obs_mean, obs_cov, obs, lambda x: batched_jacobian(obs, x))
#
# File ~/dev/github/rolandbernard/capstone-project/code/kalman.py:154, in batched_jacobian(f, x)
#     150 """
#     151 Compute the Jacobian over arbitrarily batch dimension of the given function f.
#     152 """
#     153 *Bs, N = x.shape
# --> 154 jac_flat = torch.vmap(torch.func.jacrev(f))(x.view(-1, N))
#     155 *_, M, N = jac_flat.shape
#     156 return jac_flat.reshape(*Bs, M, N)
#
# File ~/dev/github/rolandbernard/capstone-project/venv/lib64/python3.14/site-packages/torch/_functorch/apis.py:220, in vmap.<locals>.wrapped(*args, **kwargs)
#     218 def wrapped(*args: _P.args, **kwargs: _P.kwargs) -> _R:
#     219     # pyrefly: ignore[bad-argument-type]
# --> 220     return vmap_impl(
#     221         # pyrefly: ignore[bad-argument-type]
#     222         func,
#     223         in_dims,
#     224         out_dims,
#     225         randomness,
#     226         chunk_size,
#     227         *args,
#     228         **kwargs,
#     229     )
#
# File ~/dev/github/rolandbernard/capstone-project/venv/lib64/python3.14/site-packages/torch/_functorch/vmap.py:316, in vmap_impl(func, in_dims, out_dims, randomness, chunk_size, *args, **kwargs)
#     305     return _chunked_vmap(
#     306         func,
#     307         flat_in_dims,
#    (...)    312         **kwargs,
#     313     )
#     315 # If chunk_size is not specified.
# --> 316 return _flat_vmap(
#     317     func,
#     318     batch_size,
#     319     flat_in_dims,
#     320     flat_args,
#     321     args_spec,
#     322     out_dims,
#     323     randomness,
#     324     **kwargs,
#     325 )
#
# File ~/dev/github/rolandbernard/capstone-project/venv/lib64/python3.14/site-packages/torch/_functorch/vmap.py:507, in _flat_vmap(func, batch_size, flat_in_dims, flat_args, args_spec, out_dims, randomness, **kwargs)
#     503 with vmap_increment_nesting(batch_size, randomness) as vmap_level:
#     504     batched_inputs = _create_batched_inputs(
#     505         flat_in_dims, flat_args, vmap_level, args_spec
#     506     )
# --> 507     batched_outputs = func(*batched_inputs, **kwargs)
#     508     return _unwrap_batched(batched_outputs, out_dims, vmap_level, batch_size, func)
#
# File ~/dev/github/rolandbernard/capstone-project/venv/lib64/python3.14/site-packages/torch/_functorch/eager_transforms.py:774, in jacrev.<locals>.wrapper_fn(*args)
#     772     flat_jacobians_per_input = compute_jacobian_preallocate_and_copy()
#     773 else:
# --> 774     flat_jacobians_per_input = compute_jacobian_stacked()
#     776 # Step 2: The returned jacobian is one big tensor per input. In this step,
#     777 # we split each Tensor by output.
#     778 flat_jacobians_per_input = [
#     779     result.split(flat_output_numels, dim=0)
#     780     for result in flat_jacobians_per_input
#     781 ]
#
# File ~/dev/github/rolandbernard/capstone-project/venv/lib64/python3.14/site-packages/torch/_functorch/eager_transforms.py:685, in jacrev.<locals>.wrapper_fn.<locals>.compute_jacobian_stacked()
#     677             raise AssertionError(
#     678                 f"expected t.size(0) to be 1, got {t.size(0)}"
#     679             )
#     681     flat_basis_chunk = tree_map(
#     682         lambda t: torch.squeeze(t, 0), flat_basis_chunk
#     683     )
# --> 685 basis = tree_unflatten(flat_basis_chunk, output_spec)
#     687 if chunk_size == 1:
#     688     # Behaviour with `chunk_size=1` is same as `for-loop`
#     689     # i.e. user shouldn't deal with the limitations of vmap.
#     690     chunked_result = vjp_fn(basis)
#
# File ~/dev/github/rolandbernard/capstone-project/venv/lib64/python3.14/site-packages/torch/utils/_pytree.py:1489, in tree_unflatten(leaves, treespec)
#    1485     treespec = helper(tree, leaves)
#    1486     return leaves, treespec
# -> 1489 def tree_unflatten(leaves: Iterable[Any], treespec: TreeSpec) -> PyTree:
#    1490     """Given a list of values and a TreeSpec, builds a pytree.
#    1491     This is the inverse operation of `tree_flatten`.
#    1492     """
#    1493     if not _is_pytreespec_instance(treespec):
#
# KeyboardInterrupt:
