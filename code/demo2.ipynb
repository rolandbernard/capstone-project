# %%
from kalman import LinearPhysics
from tracker import Tracker
from detect import PoseDetector
from camera import Camera

import json
import cv2
import torch
torch.set_float32_matmul_precision('high')

# %%
scene = "160224_haggling1"
frames = []
all_cams = []
all_caps = []

cams = ["01_01", "06_15", "14_03", "19_14"]
with open(f"./data/panoptic/{scene}/calibration.json") as f:
    calib = json.load(f)

for i in range(4):
    cap = cv2.VideoCapture(f"./data/panoptic/{scene}/vga_{cams[i]}.mp4")
    for _ in range(100):
        ret, frame = cap.read()
        assert ret
    frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)  # type: ignore
    frame = torch.from_numpy(frame).to("cuda")
    frames.append(frame)
    all_caps.append(cap)
    cam = Camera()
    cam_calib = [c for c in calib["cameras"] if c["name"] == cams[i]][0]
    cam.intrinsic = torch.tensor(cam_calib["K"])
    cam.distortion = torch.tensor(cam_calib["distCoef"])
    cam.rotation = torch.tensor(cam_calib["R"])
    cam.translation = torch.tensor(cam_calib["t"]).squeeze(-1)
    cam.to("cuda")
    all_cams.append(cam)

# %%
detect = PoseDetector()
detect.to("cuda")

# %%
dyn_mat = torch.concat([
    torch.concat([torch.zeros(17*3, 17*3), torch.eye(3*17)], dim=1),
    torch.concat([torch.zeros(17*3, 17*3), torch.eye(3*17)*-1.0], dim=1)
], dim=0)
dyn_cov = torch.diag(torch.tensor([50]*3*17 + [50000.0]*3*17))
init_mean = torch.zeros(17*3 + 17*3)
init_cov = torch.diag(torch.concat([
    torch.full((17*3,), 200.0**2),
    torch.full((17*3,), 1000.0**2),
]))

physics = LinearPhysics(dyn_mat, dyn_cov, init_mean, init_cov)
physics.to("cuda")

# %%
tracker = Tracker(detect, physics)

# %%
cams = all_cams
imgs = frames

detections = detect.detect(cams, imgs)

# %%
import matplotlib.pyplot as plt

def plt_detect(cam, detections, axes, i = 0):
    skeleton = [[15, 13], [13, 11], [16, 14], [14, 12], [11, 12], [5, 11], [6, 12], [5, 6], [5, 7], [6, 8], [7, 9], [8, 10], [1, 2], [0, 1], [0, 2], [1, 3], [2, 4], [3, 5], [4, 6]]
    kpts = cam.distort_points(detections[0].view(-1, 17, 2))
    # for kp, cov in zip(kpts[i:i+1].cpu(), detections[1][i:i+1].cpu()):
    for kp, cov in zip(kpts.cpu(), detections[1].cpu()):
        cov = torch.diag(cov).view(17, 2)
        for i, j in skeleton:
            if cov[i, 0] < 0.5 and cov[j, 0] < 0.5:
                axes.plot([kp[i, 0], kp[j, 0]], [kp[i, 1], kp[j, 1]], color='red', linewidth=2)
        for k in range(17):
            if cov[k, 0] < 0.5:
                axes.scatter(kp[k, 0], kp[k, 1], s=20, color='#0000ff70')

_, axs = plt.subplots(2, 2, figsize=(10, 8))
axs[0, 0].imshow(imgs[0].cpu().numpy())
plt_detect(cams[0], detections[0], axs[0, 0], 0)
axs[0, 0].axis("off")
axs[0, 1].imshow(imgs[1].cpu().numpy())
plt_detect(cams[1], detections[1], axs[0, 1], 12)
axs[0, 1].axis("off")
axs[1, 0].imshow(imgs[2].cpu().numpy())
plt_detect(cams[2], detections[2], axs[1, 0], 8)
axs[1, 0].axis("off")
axs[1, 1].imshow(imgs[3].cpu().numpy())
plt_detect(cams[3], detections[3], axs[1, 1], 1)
axs[1, 1].axis("off")

plt.tight_layout()
plt.show()

# %%
tracker.update(all_cams, frames)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 tracker.update(all_cams, frames)
#
# File ~/dev/github/rolandbernard/capstone-project/code/tracker.py:267, in Tracker.update(self, cams, imgs)
#     262 """
#     263 Update the internal track states based on new incoming images, but don't
#     264 perform any internal time step updates.
#     265 """
#     266 # Perform 2d detection on each image.
# --> 267 detections = self.detector.detect(cams, imgs)
#     268 # Match each images detections to tracks.
#     269 obs: list[tuple[list[Camera], list[torch.Tensor], list[torch.Tensor]]] \
#     270     = [([], [], []) for _ in range(len(self.tracks))]
#
# File ~/dev/github/rolandbernard/capstone-project/code/detect.py:78, in PoseDetector.detect(self, cams, images)
#      70 def detect(self, cams: list[Camera], images: torch.Tensor | list[torch.Tensor]) -> list[tuple[torch.Tensor, torch.Tensor]]:
#      71     """
#      72     This is like `detect_simple`, but the returned keypoints are in normalized
#      73     camera coordinates rather than in pixel space, effectively removing the
#      74     camera intrinsics.
#      75     """
#      76     return [
#      77         (cam.undistort_points(pos), cam.undistort_covars(cov))
# ---> 78         for cam, (pos, cov) in zip(cams, self.detect_simple(images))
#      79     ]
#
# File ~/dev/github/rolandbernard/capstone-project/code/detect.py:50, in PoseDetector.detect_simple(self, images)
#      48 if images.dtype == torch.uint8:
#      49     images = images.to(torch.float32) / 255.0
# ---> 50 pred, _ = self.model(images)
#      51 results = []
#      52 for img_res in pred:
#
# File ~/dev/github/rolandbernard/capstone-project/venv/lib64/python3.14/site-packages/torch/nn/modules/module.py:1776, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1774 def _wrapped_call_impl(self, *args, **kwargs):
#    1775     if self._compiled_call_impl is not None:
# -> 1776         return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1777     else:
#    1778         return self._call_impl(*args, **kwargs)
#
# File ~/dev/github/rolandbernard/capstone-project/venv/lib64/python3.14/site-packages/torch/_dynamo/eval_frame.py:1047, in _TorchDynamoContext.__call__.<locals>.compile_wrapper(*args, **kwargs)
#    1045 call_succeeded = False
#    1046 try:
# -> 1047     result = fn(*args, **kwargs)
#    1048     call_succeeded = True
#    1049 except (Unsupported, UncapturedHigherOrderOpError, UserError) as e:
#
# File ~/dev/github/rolandbernard/capstone-project/venv/lib64/python3.14/site-packages/torch/nn/modules/module.py:1789, in Module._call_impl(self, *args, **kwargs)
#    1784 # If we don't have any hooks, we want to skip the rest of the logic in
#    1785 # this function, and just call forward.
#    1786 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1787         or _global_backward_pre_hooks or _global_backward_hooks
#    1788         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1789     return forward_call(*args, **kwargs)
#    1791 result = None
#    1792 called_always_called_hooks = set()
#
# File ~/dev/github/rolandbernard/capstone-project/venv/lib64/python3.14/site-packages/torch/_dynamo/convert_frame.py:2474, in CatchErrorsWrapper.__call__(self, frame, cache_entry, frame_state)
#    2468             return hijacked_callback(
#    2469                 frame, cache_entry, self.hooks, frame_state
#    2470             )
#    2472 with compile_lock, _disable_current_modes():
#    2473     # skip=1: skip this frame
# -> 2474     result = self._torchdynamo_orig_backend(
#    2475         frame, cache_entry, self.hooks, frame_state, skip=1
#    2476     )
#    2477     return result
#
# File ~/dev/github/rolandbernard/capstone-project/venv/lib64/python3.14/site-packages/torch/_dynamo/convert_frame.py:2192, in ConvertFrame.__call__(self, frame, cache_entry, hooks, frame_state, skip)
#    2190 counters["frames"]["total"] += 1
#    2191 try:
# -> 2192     result = self._inner_convert(
#    2193         frame, cache_entry, hooks, frame_state, skip=skip + 1
#    2194     )
#    2195     counters["frames"]["ok"] += 1
#    2196     return result
#
# File ~/dev/github/rolandbernard/capstone-project/venv/lib64/python3.14/site-packages/torch/_dynamo/convert_frame.py:736, in ConvertFrameAssert.__call__(self, frame, cache_entry, hooks, frame_state, skip)
#     730     recompile_ctx = (
#     731         config.patch(recompile_limit=self._recompile_limit)
#     732         if self._recompile_limit is not None
#     733         else contextlib.nullcontext()
#     734     )
#     735     with compile_ctx, recompile_ctx:
# --> 736         result = _compile(
#     737             frame.f_code,
#     738             frame.f_globals,
#     739             frame.f_locals,
#     740             frame.f_builtins,
#     741             frame.closure,
#     742             self._torchdynamo_orig_backend,
#     743             self._one_graph,
#     744             self._export,
#     745             self._export_constraints,
#     746             hooks,
#     747             cache_entry,
#     748             cache_size,
#     749             frame,
#     750             frame_state=frame_state,
#     751             compile_id=compile_id,
#     752             skip=skip + 1,
#     753             package=self._package,
#     754             convert_frame_box=self._box,
#     755         )
#     756 finally:
#     757     # Restore the previous initial_global_state for nested compilation handling
#     758     initial_global_state = prev_initial_global_state
#
# File ~/dev/github/rolandbernard/capstone-project/venv/lib64/python3.14/site-packages/torch/_dynamo/convert_frame.py:1961, in _compile(code, globals, locals, builtins, closure, compiler_fn, one_graph, export, export_constraints, hooks, cache_entry, cache_size, frame, frame_state, compile_id, skip, package, convert_frame_box)
#    1958         raise ValueError(err)
#    1960 try:
# -> 1961     guarded_code, tracer_output = compile_inner(code, one_graph, hooks)
#    1963     # NB: We only put_code_state in success case.  Success case here
#    1964     # does include graph breaks; specifically, if a graph break still
#    1965     # resulted in a partially compiled graph, we WILL return here.  An
#    (...)   1970     # to upload for graph break though, because this can prevent
#    1971     # extra graph break compilations.)
#    1972     put_code_state()
#
# File ~/dev/github/rolandbernard/capstone-project/venv/lib64/python3.14/site-packages/torch/_utils_internal.py:96, in compile_time_strobelight_meta.<locals>.compile_time_strobelight_meta_inner.<locals>.wrapper_function(*args, **kwargs)
#      93 # This is not needed but we have it here to avoid having profile_compile_time
#      94 # in stack traces when profiling is not enabled.
#      95 if not StrobelightCompileTimeProfiler.enabled:
# ---> 96     return function(*args, **kwargs)
#      98 return StrobelightCompileTimeProfiler.profile_compile_time(
#      99     function, phase_name, *args, **kwargs
#     100 )
#
# File ~/dev/github/rolandbernard/capstone-project/venv/lib64/python3.14/site-packages/torch/_dynamo/convert_frame.py:1571, in _compile.<locals>.compile_inner(code, one_graph, hooks)
#    1569 stack.enter_context(CompileTimeInstructionCounter.record())
#    1570 stack.enter_context(torch_function_mode_stack_state_mgr)
# -> 1571 result = _compile_inner(code, one_graph, hooks)
#    1572 assert torch._C._len_torch_function_stack() == 0, (
#    1573     "Torch function mode stack state changed while dynamo tracing, please report a bug"
#    1574 )
#    1575 return result
#
# File ~/dev/github/rolandbernard/capstone-project/venv/lib64/python3.14/site-packages/torch/_dynamo/convert_frame.py:1630, in _compile.<locals>._compile_inner(code, one_graph, hooks)
#    1624 try:
#    1625     with (
#    1626         config.patch(dynamo_config_override)
#    1627         if dynamo_config_override
#    1628         else contextlib.nullcontext()
#    1629     ):
# -> 1630         dynamo_output = compile_frame(
#    1631             code,
#    1632             globals,
#    1633             locals,
#    1634             builtins,
#    1635             closure,
#    1636             compiler_fn,
#    1637             one_graph,
#    1638             restart_reasons,
#    1639             export=export,
#    1640             export_constraints=export_constraints,
#    1641             frame_state=frame_state,
#    1642             distributed_state=distributed_state,
#    1643             package=package,
#    1644         )
#    1645 except exc.SkipFrame as e:
#    1646     if one_graph:
#
# File ~/dev/github/rolandbernard/capstone-project/venv/lib64/python3.14/site-packages/torch/_dynamo/convert_frame.py:1478, in compile_frame(code, globals, locals, builtins, closure, compiler_fn, one_graph, restart_reasons, export, export_constraints, frame_state, distributed_state, package)
#    1476 try:
#    1477     with dynamo_timed(f"compile_attempt_{attempt}", log_pt2_compile_event=True):
# -> 1478         bytecode, tracer_output = transform_code_object(code, transform)
#    1479         assert tracer_output is not None
#    1480         return DynamoOutput(
#    1481             tracer_output=tracer_output,
#    1482             bytecode=bytecode,
#    1483             last_attempt_start_time=last_attempt_start_time,
#    1484         )
#
# File ~/dev/github/rolandbernard/capstone-project/venv/lib64/python3.14/site-packages/torch/_dynamo/bytecode_transformation.py:1626, in transform_code_object(code, transformations, safe)
#    1623 # propagate line nums again for added instructions
#    1624 propagate_line_nums(instructions)
# -> 1626 tracer_output = transformations(instructions, code_options)
#    1627 _, bytecode = clean_and_assemble_instructions(instructions, keys, code_options)
#    1628 return bytecode, tracer_output
#
# File ~/dev/github/rolandbernard/capstone-project/venv/lib64/python3.14/site-packages/torch/_dynamo/convert_frame.py:1450, in compile_frame.<locals>.transform(instructions, code_options)
#    1444 def transform(
#    1445     instructions: list[Instruction], code_options: dict[str, object]
#    1446 ) -> DynamoTracerOutput:
#    1447     tf_mode_stack: list[torch.overrides.TorchFunctionMode] = list(
#    1448         torch_function_mode_stack_state_mgr.stack
#    1449     )
# -> 1450     tracer_output = trace_frame(
#    1451         code,
#    1452         globals,
#    1453         locals,
#    1454         builtins,
#    1455         closure,
#    1456         compiler_fn,
#    1457         tf_mode_stack,
#    1458         one_graph,
#    1459         speculation_log,
#    1460         instructions,
#    1461         code_options,
#    1462         export=export,
#    1463         export_constraints=export_constraints,
#    1464         frame_state=frame_state,
#    1465         distributed_state=distributed_state,
#    1466         package=package,
#    1467     )
#    1469     assert tracer_output is not None
#    1470     return tracer_output
#
# File ~/dev/github/rolandbernard/capstone-project/venv/lib64/python3.14/site-packages/torch/_dynamo/convert_frame.py:343, in preserve_global_state.<locals>._fn(*args, **kwargs)
#     341 reset_user_object_tracking()
#     342 try:
# --> 343     return fn(*args, **kwargs)
#     344 finally:
#     345     cleanup.close()
#
# File ~/dev/github/rolandbernard/capstone-project/venv/lib64/python3.14/site-packages/torch/_dynamo/convert_frame.py:911, in trace_frame(code, globals, locals, builtins, closure, compiler_fn, tf_mode_stack, one_graph, speculation_log, instructions, code_options, export, export_constraints, frame_state, distributed_state, package)
#     908         tracer.f_locals = {}
#     910 try:
# --> 911     run_tracer()
#     912     tracer_output = DynamoTracerOutput(tracer)
#     913     output = tracer_output.output_graph
#
# File ~/dev/github/rolandbernard/capstone-project/venv/lib64/python3.14/site-packages/torch/_dynamo/convert_frame.py:892, in trace_frame.<locals>.run_tracer()
#     890     tracer.output.mark_bytecode_tracing_start()
#     891     with tracing(tracer.output.tracing_context), tracer.set_current_tx():
# --> 892         tracer.run()
#     893 except exc.UnspecializeRestartAnalysis:
#     894     speculation_log.clear()  # type: ignore[has-type]
#
# File ~/dev/github/rolandbernard/capstone-project/venv/lib64/python3.14/site-packages/torch/_dynamo/symbolic_convert.py:1813, in InstructionTranslatorBase.run(self)
#    1811 self.start_point = self.instruction_pointer
#    1812 try:
# -> 1813     while self.step():
#    1814         pass
#    1815 except Exception as e:
#
# File ~/dev/github/rolandbernard/capstone-project/venv/lib64/python3.14/site-packages/torch/_dynamo/symbolic_convert.py:1480, in InstructionTranslatorBase.step(self)
#    1477 self.update_block_stack(inst)
#    1479 try:
# -> 1480     self.dispatch_table[inst.opcode](self, inst)
#    1481     return not self.output.should_exit
#    1482 except TensorifyScalarRestartAnalysis:
#
# File ~/dev/github/rolandbernard/capstone-project/venv/lib64/python3.14/site-packages/torch/_dynamo/symbolic_convert.py:5143, in InstructionTranslator.RETURN_VALUE(self, inst)
#    5142 def RETURN_VALUE(self, inst: Instruction) -> None:
# -> 5143     self._return(inst)
#
# File ~/dev/github/rolandbernard/capstone-project/venv/lib64/python3.14/site-packages/torch/_dynamo/symbolic_convert.py:5125, in InstructionTranslator._return(self, inst)
#    5120 _step_logger()(
#    5121     logging.INFO,
#    5122     f"torchdynamo done tracing {self.f_code.co_name} ({inst.opname})",
#    5123 )
#    5124 log.debug("return triggered compile")
# -> 5125 all_stack_locals_metadata = self.output.compile_subgraph(
#    5126     self,
#    5127     reason=GraphCompileReason(
#    5128         "return_value", [self.frame_summary()], graph_break=False
#    5129     ),
#    5130     # the value to be returned
#    5131     stack_pops=1 if inst.opname == "RETURN_VALUE" else 0,
#    5132 )
#    5133 # check that our stack/locals meta are correct:
#    5134 # we should only be tracing 1 frame, and there should not be any NULLs on the stack
#    5135 assert len(all_stack_locals_metadata) == 1
#
# File ~/dev/github/rolandbernard/capstone-project/venv/lib64/python3.14/site-packages/torch/_dynamo/output_graph.py:1897, in OutputGraph.compile_subgraph(self, tx, reason, stack_pops)
#    1894     cur_tx = cur_tx.parent
#    1896 # "Garbage collect the heap".
# -> 1897 self.side_effects.prune_dead_object_new(tx)
#    1899 self.add_output_instructions(prefix_insts)
#    1901 if self._emit_debugger_breakpoint:
#
# File ~/dev/github/rolandbernard/capstone-project/venv/lib64/python3.14/site-packages/torch/_dynamo/side_effects.py:727, in SideEffects.prune_dead_object_new(self, tx)
#     725         init_live_vars.append(cur_tx.post_prune_cell_and_freevars)
#     726     cur_tx = cur_tx.parent
# --> 727 VariableTracker.visit(
#     728     visit,
#     729     # TODO track from all possible sources.
#     730     init_live_vars
#     731     + [
#     732         pre_existing_vars,
#     733         tx.output.backward_state,
#     734         self.tensor_hooks,
#     735     ],
#     736 )
#     737 # Manually release the self-referential function, which indirectly
#     738 # captures certain `VariableTracker` and affects parts of PT test/logic
#     739 # that are sensitive to when certain objects get released.
#     740 del visit
#
# File ~/dev/github/rolandbernard/capstone-project/venv/lib64/python3.14/site-packages/torch/_dynamo/variables/base.py:346, in VariableTracker.visit(cls, fn, value, cache, side_effects)
#     344 elif istype(value, (list, tuple)):
#     345     for subvalue in value:
# --> 346         cls.visit(fn, subvalue, cache, side_effects)
#     347 elif istype(value, (dict, collections.OrderedDict)):
#     348     for subvalue in value.values():
#
# File ~/dev/github/rolandbernard/capstone-project/venv/lib64/python3.14/site-packages/torch/_dynamo/variables/base.py:346, in VariableTracker.visit(cls, fn, value, cache, side_effects)
#     344 elif istype(value, (list, tuple)):
#     345     for subvalue in value:
# --> 346         cls.visit(fn, subvalue, cache, side_effects)
#     347 elif istype(value, (dict, collections.OrderedDict)):
#     348     for subvalue in value.values():
#
# File ~/dev/github/rolandbernard/capstone-project/venv/lib64/python3.14/site-packages/torch/_dynamo/variables/base.py:340, in VariableTracker.visit(cls, fn, value, cache, side_effects)
#     338 for key, subvalue in value.__dict__.items():
#     339     if key not in nonvars:
# --> 340         cls.visit(fn, subvalue, cache, side_effects)
#     341 if side_effects is not None and value in side_effects.store_attr_mutations:
#     342     for attr_vt in side_effects.store_attr_mutations[value].values():
#
# File ~/dev/github/rolandbernard/capstone-project/venv/lib64/python3.14/site-packages/torch/_dynamo/variables/base.py:349, in VariableTracker.visit(cls, fn, value, cache, side_effects)
#     347 elif istype(value, (dict, collections.OrderedDict)):
#     348     for subvalue in value.values():
# --> 349         cls.visit(fn, subvalue, cache, side_effects)
#
# File ~/dev/github/rolandbernard/capstone-project/venv/lib64/python3.14/site-packages/torch/_dynamo/variables/base.py:339, in VariableTracker.visit(cls, fn, value, cache, side_effects)
#     337 nonvars = value._nonvar_fields
#     338 for key, subvalue in value.__dict__.items():
# --> 339     if key not in nonvars:
#     340         cls.visit(fn, subvalue, cache, side_effects)
#     341 if side_effects is not None and value in side_effects.store_attr_mutations:
#
# KeyboardInterrupt:

# %%
for i in range(1, 1500):
    tracker.predict(1 / 25)
    frames = []
    for cap in all_caps:
        ret, frame = cap.read()
        assert ret
        frame = torch.from_numpy(frame).to("cuda")
        frames.append(frame)
        
    tracker.update(all_cams, frames)
    with open(f"data/demo2/{i}.json", "w") as file:
        tracks = [{
            "id": track.id,
            "kpts": (track.get_keypoints() / 100).tolist(),
            "covs": (track.get_covariances() / 10000).tolist()
        } for track in tracker.get_prediction()]
        json.dump(tracks, file)

# %%
tracker.tracks[0].num_detection
# Out:
# 1500
