# %% [markdown]
# # Training (Parameters)
#
# This notebook contains the code used to perform the joint training loop that combines training of both the Kalman filter parameters as well as the YOLO uncertainty head.

# %%
# TODO
