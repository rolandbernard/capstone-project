# %% [markdown]
# # Data Exploration
#
# This notebook contains the initial data exploration performed for this project. It analyzes multiple aspects of the chosen dataset to better understand the problem and to enable better analysis of the final results.

# %%
# TODO
